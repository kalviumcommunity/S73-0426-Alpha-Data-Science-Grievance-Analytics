# %% [markdown]
# # Jupyter Notebook: Code and Markdown Demonstration
#
# This notebook demonstrates the proper use of Code and Markdown cells for clear and structured data science workflows.

# %% [markdown]
# ## Explanation of First Code Block
#
# The following code cell prints a simple message to verify that Python execution is working correctly.

# %%
print("Hello, this is my first code cell!")

# %% [markdown]
# ## Explanation of Second Code Block
#
# The following code cell performs a basic arithmetic operation to demonstrate simple Python computation.

# %%
result = 10 + 5
print("The result is:", result)
